# %% [markdown]
# # Tarea - Ajuste de curvas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ---
# ### Problema 1
#
# Los siguientes datos representan el costo en dólares de la electricidad según Western Electricity Coordinating Council desde el 2014 (y su pronóstico para el 2040)
#
# Tomado de:
# https://www.quandl.com/data/EIA/AEO_2016_REF_NO_CPP_PRCE_NA_COMM_NA_ELC_NA_WECCRKS_NCNTPKWH_A-Electricity-End-Use-Prices-Commercial-Western-Electricity-Coordinating-Council-Rockies-No-CPP-AEO2016

# %%
import numpy as np
# Datos extraidos de la página de quandl
data = np.array([10.051101,  9.259127,  9.444813,  9.557723,  9.977324, 10.298326,
       10.447217, 10.550506, 10.590784, 10.657418, 10.743085, 10.831965,
       10.988435, 11.153055, 11.313326, 11.557165, 11.860136, 12.122511,
       12.356448, 12.611391, 12.814569, 13.111372, 13.357134, 13.559012,
       13.85861 , 14.135924, 14.436149])

# %% [markdown]
# 1. Ajuste estos datos a polinomios de grado 1 hasta 3 (los datos en $x$ corresponden a los años de 2014 a 2040, sin embargo son valores muy grandes para elevarlos a una potencia, use una representación para estos años, por ejemplo $2014 \rightarrow 0$ y $2040\rightarrow 26$).
#
# 2. Muestre las tres curvas ajustadas junto a los datos de los costos en un solo gráfico

# %%
import numpy as np
import matplotlib.pyplot as plt

años = np.arange(0, 27)

costo = np.array([10.051101, 9.259127, 9.444813, 9.557723, 9.977324, 10.298326,
    10.447217, 10.550506, 10.590784, 10.657418, 10.743085, 10.831965,
    10.988435, 11.153055, 11.313326, 11.557165, 11.860136, 12.122511,
    12.356448, 12.611391, 12.814569, 13.111372, 13.357134, 13.559012,
    13.85861 , 14.135924, 14.436149])

# %%
p1 = np.polyfit(años, costo, 1)
p2 = np.polyfit(años, costo, 2)
p3 = np.polyfit(años, costo, 3)

# %%
y1 = np.polyval(p1, años)
y2 = np.polyval(p2, años)
y3 = np.polyval(p3, años)

# %%
plt.plot(años, costo, 'o', label='Datos')
plt.plot(años, y1, '-', label='Ajuste grado 1')
plt.plot(años, y2, '-', label='Ajuste grado 2')
plt.plot(años, y3, '-', label='Ajuste grado 3')

plt.xlabel('Año (desde 2014)')
plt.ylabel('Costo de la electricidad (USD)')
plt.legend()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ___
# ### Problema 2
#
# El archivo `population_data.csv` contiene información histórica anual de México relativa a la población, nacimientos y muertes desde el año 1950 hasta el año 2015. La primer columna corresponde a los años, la segunda a la población, la tercera a los nacimientos y la última a los decesos.
#
# Tomado de: https://en.wikipedia.org/wiki/Demographics_of_Mexico.
#
# Importe estos datos usando la función `read_csv` del paquete `pandas`
#
# 1. Usando los años como variable independiente $x$ y la población como variable dependiente $y$, ajustar polinomios de grado 1 hasta grado 3.
#
#     * Mostrar en un solo gráfico los datos de población contra los años, y los polinomios ajustados.
#
#     * Graficar el error cuadrático acumulado contra el número de términos.
#
# 2. Repetir el punto 1 usando los nacimientos como variable dependiente $y$. Grafique las curvas ajustadas junto con los datos de nacimientos. Vea en un gráfico el error acumulado.

# %% [markdown]
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv('population_data.csv')
años = data['Year']
poblacion = data['Population']
nacimientos = data['Births']
defunciones = data['Deaths']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 5
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 5 data = pd.read_csv('population_data.csv')
#       6 años = data['Year']
#       7 poblacion = data['Population']
#
# File /lib/python3.11/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File /lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
# ...

# %%
p1_poblacion = np.polyfit(años, poblacion, 1)
p2_poblacion = np.polyfit(años, poblacion, 2)
p3_poblacion = np.polyfit(años, poblacion, 3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 p1_poblacion = np.polyfit(años, poblacion, 1)
#       2 p2_poblacion = np.polyfit(años, poblacion, 2)
#       3 p3_poblacion = np.polyfit(años, poblacion, 3)
#
# NameError: name 'poblacion' is not defined

# %%
y1_poblacion = np.polyval(p1_poblacion, años)
y2_poblacion = np.polyval(p2_poblacion, años)
y3_poblacion = np.polyval(p3_poblacion, años)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 y1_poblacion = np.polyval(p1_poblacion, años)
#       2 y2_poblacion = np.polyval(p2_poblacion, años)
#       3 y3_poblacion = np.polyval(p3_poblacion, años)
#
# NameError: name 'p1_poblacion' is not defined

# %%
p1_nacimientos = np.polyfit(años, nacimientos, 1)
p2_nacimientos = np.polyfit(años, nacimientos, 2)
p3_nacimientos = np.polyfit(años, nacimientos, 3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 p1_nacimientos = np.polyfit(años, nacimientos, 1)
#       2 p2_nacimientos = np.polyfit(años, nacimientos, 2)
#       3 p3_nacimientos = np.polyfit(años, nacimientos, 3)
#
# NameError: name 'nacimientos' is not defined

# %%
y1_nacimientos = np.polyval(p1_nacimientos, años)
y2_nacimientos = np.polyval(p2_nacimientos, años)
y3_nacimientos = np.polyval(p3_nacimientos, años)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 y1_nacimientos = np.polyval(p1_nacimientos, años)
#       2 y2_nacimientos = np.polyval(p2_nacimientos, años)
#       3 y3_nacimientos = np.polyval(p3_nacimientos, años)
#
# NameError: name 'p1_nacimientos' is not defined

# %%
plt.plot(años, poblacion, 'o', label='Datos Población')
plt.plot(años, y1_poblacion, '-', label='Ajuste Población Grado 1')
plt.plot(años, y2_poblacion, '-', label='Ajuste Población Grado 2')
plt.plot(años, y3_poblacion, '-', label='Ajuste Población Grado 3')

plt.xlabel('Año')
plt.ylabel('Población')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 plt.plot(años, poblacion, 'o', label='Datos Población')
#       2 plt.plot(años, y1_poblacion, '-', label='Ajuste Población Grado 1')
#       3 plt.plot(años, y2_poblacion, '-', label='Ajuste Población Grado 2')
#
# NameError: name 'poblacion' is not defined
