# %% [markdown]
# #### EJERCICIO 1 BOSTON HOUSING

# %%
import pandas as pd

data = pd.read_excel("Boston Housing Dataset 1978.xlsx")
data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
data.head(5)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
data.tail(5)
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9

# %%
data["CRIM"]
# Out:
# 0      0.00632
# 1      0.02731
# 2      0.02729
# 3      0.03237
# 4      0.06905
#         ...
# 501    0.06263
# 502    0.04527
# 503    0.06076
# 504    0.10959
# 505    0.04741
# Name: CRIM, Length: 506, dtype: float64

# %%
data.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
data.plot()
# Out:
# <Axes: >

# %%
data.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     1.269195   13.295257    9.205158    0.140765    1.101175   15.679800
# std      2.399207   23.048697    7.169630    0.312765    1.646991   27.220206
# min      0.000000    0.000000    0.000000    0.000000    0.385000    3.561000
# 25%      0.049443    0.000000    3.440000    0.000000    0.449000    5.961500
# 50%      0.144655    0.000000    6.960000    0.000000    0.538000    6.322500
# 75%      0.819623   18.100000   18.100000    0.000000    0.647000    6.949000
# max      9.966540  100.000000   27.740000    1.000000    7.313000  100.000000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    58.744660    6.173308   78.063241  339.317787   42.614980  332.791107
# ...

# %%
data.boxplot()
# Out:
# <Axes: >

# %%
columnas = ["INDUS", "AGE", "TAX", "RAD", "MEDV"]

datos_filtrados = data[columnas]
datos_filtrados
# Out:
#      INDUS   AGE    TAX  RAD  MEDV
# 0     2.31  65.2  296.0    1  24.0
# 1     7.07  78.9  242.0    2  21.6
# 2     7.07  61.1  242.0    2  34.7
# 3     2.18  45.8  222.0    3  33.4
# 4     2.18  54.2  222.0    3  36.2
# ..     ...   ...    ...  ...   ...
# 501  11.93  69.1  273.0    1  22.4
# 502  11.93  76.7  273.0    1  20.6
# 503  11.93  91.0  273.0    1  23.9
# 504  11.93  89.3  273.0    1  22.0
# 505  11.93  80.8  273.0    1  11.9
#
# [506 rows x 5 columns]

# %%
age = datos_filtrados["AGE"]
age = age - min(age)
age = age/max(age)
age.describe()

def scaler(variable) : 
    variable = variable - min(variable)
    variable = variable/max(variable)
    return variable

datos_filtrados.loc[:,"INDUS"] = scaler(datos_filtrados["INDUS"])
datos_filtrados.loc[:,"AGE"] = scaler(datos_filtrados["AGE"])
datos_filtrados.loc[:,"TAX"] = scaler(datos_filtrados["TAX"])
datos_filtrados.loc[:,"RAD"] = scaler(datos_filtrados["RAD"])

datos_filtrados.describe()
# Out:
#             INDUS         AGE         TAX         RAD        MEDV
# count  506.000000  506.000000  506.000000  506.000000  452.000000
# mean     0.331837    0.582702    0.461954    0.115885   23.750442
# std      0.258458    0.334848    0.261537    0.306078    8.808602
# min      0.000000    0.000000    0.000000    0.000000    6.300000
# 25%      0.124009    0.312179    0.338448    0.004511   18.500000
# 50%      0.250901    0.648503    0.415171    0.006015   21.950000
# 75%      0.652487    0.898597    0.554140    0.034586   26.600000
# max      1.000000    1.000000    1.000000    1.000000   50.000000

# %%
datos_filtrados = datos_filtrados.dropna()
datos_filtrados.describe()
# Out:
#             INDUS         AGE         TAX         RAD        MEDV
# count  452.000000  452.000000  452.000000  452.000000  452.000000
# mean     0.371481    0.651619    0.517143    0.010260   23.750442
# std      0.245029    0.284505    0.219061    0.011344    8.808602
# min      0.016583    0.017833    0.241459    0.000000    6.300000
# 25%      0.177722    0.402709    0.371381    0.004511   18.500000
# 50%      0.293439    0.714757    0.415171    0.006015   21.950000
# 75%      0.652487    0.915287    0.565721    0.009023   26.600000
# max      1.000000    1.000000    1.000000    0.034586   50.000000

# %% [markdown]
# #### Empezar a hacer matriz de X = [1, RAD, AGE, TAX, RAD]

# %%
def funcion_de_costo(beta, x, y) :
    r, c = X.shape
    beta = np.reshape(beta, [c,1])
    y_pred = X @ beta 
    error = y_pred - y
    return (error.T @ error)[0][0]

import numpy as np

m= len(datos_filtrados["MEDV"])
ones = np.ones([m,1])
indus = np.reshape(datos_filtrados["INDUS"],[m,1])
age = np.reshape(datos_filtrados["AGE"],[m,1])
tax = np.reshape(datos_filtrados["TAX"],[m,1])
rad = np.reshape(datos_filtrados["RAD"],[m,1])
X = np.hstack( (ones, indus, age, tax, rad))
y = np.reshape(datos_filtrados["MEDV"], [m,1])

# %%
import scipy.optimize as opt
r, c = X.shape
beta = np.random.uniform(-1, 1, c)

opt.minimize(funcion_de_costo, beta, args=(X,y))
# Out:
#   message: Optimization terminated successfully.
#   success: True
#    status: 0
#       fun: 28036.267558050866
#         x: [ 3.457e+01 -8.578e+00 -2.745e+00 -1.552e+01  2.122e+02]
#       nit: 23
#       jac: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00  0.000e+00]
#  hess_inv: [[ 2.618e-03  3.467e-05 ... -3.164e-03  5.148e-03]
#             [ 3.467e-05  1.971e-02 ... -1.329e-02  2.334e-02]
#             ...
#             [-3.164e-03 -1.329e-02 ...  1.599e-02 -2.375e-02]
#             [ 5.148e-03  2.334e-02 ... -2.375e-02  5.553e-02]]
#      nfev: 204
#      njev: 34

# %% [markdown]
# #### EJERCICIO 2 MOTOR TREND

# %%
data2 = pd.read_excel("Motor Trend Car Road Tests.xlsx")
data2
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
columnas2 = ["mpg", "cyl", "disp", "hp", "drat", "wt", "qsec", "vs", "am", "gear", "carb"]

datos_filtrados2 = data2[columnas2]
datos_filtrados2
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0   21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2   22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3   21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4   18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5   18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6   14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7   24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8   22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9   19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 11  16.4    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 12  17.3    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# ...

# %%
datos_filtrados2.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %% [markdown]
# #### mpg 	Miles/(US) gallon
# #### cyl 	Number of cylinders
# #### disp	Displacement (cu.in.)
# #### hp  	Gross horsepower
# #### drat	Rear axle ratio
# #### wt  	Weight (1000 lbs)
# #### qsec	1/4 mile time
# #### vs  	Engine (0 = V-shaped, 1 = straight)
# #### am  	Transmission (0 = automatic, 1 = manual)
# #### gear	Number of forward gears

# %%
def funcion_de_costo2(beta, x, y) :
    r, c = X.shape
    beta = np.reshape(beta, [c,1])
    y_pred = X @ beta
    error = y_pred - y
    return (error.T @ error)[0][0]

import numpy as np

m= len(datos_filtrados2["mpg"])
ones = np.ones([m,1])
cyl= np.reshape(datos_filtrados2["cyl"],[m,1])
disp = np.reshape(datos_filtrados2["disp"],[m,1])
hp = np.reshape(datos_filtrados2["hp"],[m,1])
drat = np.reshape(datos_filtrados2["drat"],[m,1])
wt = np.reshape(datos_filtrados2["wt"],[m,1])
qsec = np.reshape(datos_filtrados2["qsec"],[m,1])
vs = np.reshape(datos_filtrados2["vs"],[m,1])
am = np.reshape(datos_filtrados2["am"],[m,1])
gear = np.reshape(datos_filtrados2["gear"],[m,1])
carb = np.reshape(datos_filtrados2["carb"],[m,1])

X = np.hstack( (ones, cyl, disp, hp, drat, wt, qsec, vs, am, gear, carb) )
y = np.reshape(datos_filtrados2["mpg"], [m,1])

# %%
c
# Out:
# 11

# %%
import scipy.optimize as opt

r, c = X.shape
beta = np.random.uniform(0, 1, c)

opt.minimize(funcion_de_costo2, beta, args=(X,y))
# Out:
#   message: Desired error not necessarily achieved due to precision loss.
#   success: False
#    status: 2
#       fun: 147.49443002632353
#         x: [ 1.230e+01 -1.114e-01  1.333e-02 -2.148e-02  7.871e-01
#             -3.715e+00  8.210e-01  3.178e-01  2.520e+00  6.554e-01
#             -1.994e-01]
#       nit: 26
#       jac: [ 0.000e+00  1.907e-06  2.289e-05  1.144e-05  3.815e-06
#              0.000e+00  7.629e-06  0.000e+00  0.000e+00  0.000e+00
#              0.000e+00]
#  hess_inv: [[ 6.517e-01 -3.304e-11 ... -2.862e-01  8.353e-02]
#             [-3.304e-11  6.230e-12 ...  1.820e-11 -8.145e-12]
#             ...
#             [-2.862e-01  1.820e-11 ...  4.894e-01 -2.001e-01]
#             [ 8.353e-02 -8.145e-12 ... -2.001e-01  1.058e-01]]
#      nfev: 816
#      njev: 68
